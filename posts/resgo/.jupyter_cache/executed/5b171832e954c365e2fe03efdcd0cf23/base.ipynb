# %%
# imports
import os
import sys
import types
import json
import base64

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96
interactivity = ''
is_shiny = False
is_dashboard = False
plotly_connected = True

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = "figure"
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  if plotly_connected:
    pio.renderers.default = "notebook_connected"
  else:
    pio.renderers.default = "notebook"
  for template in pio.templates.keys():
    pio.templates[template].layout.margin = dict(t=30,r=0,b=0,l=0)
except Exception:
  pass

# disable itables paging for dashboards
if is_dashboard:
  try:
    from itables import options
    options.dom = 'fiBrtlp'
    options.maxBytes = 1024 * 1024
    options.language = dict(info = "Showing _TOTAL_ entries")
    options.classes = "display nowrap compact"
    options.paging = False
    options.searching = True
    options.ordering = True
    options.info = True
    options.lengthChange = False
    options.autoWidth = False
    options.responsive = True
    options.keys = True
    options.buttons = []
  except Exception:
    pass
  
  try:
    import altair as alt
    # By default, dashboards will have container sized
    # vega visualizations which allows them to flow reasonably
    theme_sentinel = '_quarto-dashboard-internal'
    def make_theme(name):
        nonTheme = alt.themes._plugins[name]    
        def patch_theme(*args, **kwargs):
            existingTheme = nonTheme()
            if 'height' not in existingTheme:
              existingTheme['height'] = 'container'
            if 'width' not in existingTheme:
              existingTheme['width'] = 'container'

            if 'config' not in existingTheme:
              existingTheme['config'] = dict()
            
            # Configure the default font sizes
            title_font_size = 15
            header_font_size = 13
            axis_font_size = 12
            legend_font_size = 12
            mark_font_size = 12
            tooltip = False

            config = existingTheme['config']

            # The Axis
            if 'axis' not in config:
              config['axis'] = dict()
            axis = config['axis']
            if 'labelFontSize' not in axis:
              axis['labelFontSize'] = axis_font_size
            if 'titleFontSize' not in axis:
              axis['titleFontSize'] = axis_font_size  

            # The legend
            if 'legend' not in config:
              config['legend'] = dict()
            legend = config['legend']
            if 'labelFontSize' not in legend:
              legend['labelFontSize'] = legend_font_size
            if 'titleFontSize' not in legend:
              legend['titleFontSize'] = legend_font_size  

            # The header
            if 'header' not in config:
              config['header'] = dict()
            header = config['header']
            if 'labelFontSize' not in header:
              header['labelFontSize'] = header_font_size
            if 'titleFontSize' not in header:
              header['titleFontSize'] = header_font_size    

            # Title
            if 'title' not in config:
              config['title'] = dict()
            title = config['title']
            if 'fontSize' not in title:
              title['fontSize'] = title_font_size

            # Marks
            if 'mark' not in config:
              config['mark'] = dict()
            mark = config['mark']
            if 'fontSize' not in mark:
              mark['fontSize'] = mark_font_size

            # Mark tooltips
            if tooltip and 'tooltip' not in mark:
              mark['tooltip'] = dict(content="encoding")

            return existingTheme
            
        return patch_theme

    # We can only do this once per session
    if theme_sentinel not in alt.themes.names():
      for name in alt.themes.names():
        alt.themes.register(name, make_theme(name))
      
      # register a sentinel theme so we only do this once
      alt.themes.register(theme_sentinel, make_theme('default'))
      alt.themes.enable('default')

  except Exception:
    pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass

# interactivity
if interactivity:
  from IPython.core.interactiveshell import InteractiveShell
  InteractiveShell.ast_node_interactivity = interactivity

# NOTE: the kernel_deps code is repeated in the cleanup.py file
# (we can't easily share this code b/c of the way it is run).
# If you edit this code also edit the same code in cleanup.py!

# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
run_path = 'L2hvbWUvbmljay9yZXBvcy9ibG9nL3Bvc3RzL3Jlc2dv'
if run_path:
  # hex-decode the path
  run_path = base64.b64decode(run_path.encode("utf-8")).decode("utf-8")
  os.chdir(run_path)

# reset state
# %reset

# shiny
# Checking for shiny by using False directly because we're after the %reset. We don't want
# to set a variable that stays in global scope.
if False:
  try:
    import htmltools as _htmltools
    import ast as _ast

    _htmltools.html_dependency_render_mode = "json"

    # This decorator will be added to all function definitions
    def _display_if_has_repr_html(x):
      try:
        # IPython 7.14 preferred import
        from IPython.display import display, HTML
      except:
        from IPython.core.display import display, HTML

      if hasattr(x, '_repr_html_'):
        display(HTML(x._repr_html_()))
      return x

    # ideally we would undo the call to ast_transformers.append
    # at the end of this block whenver an error occurs, we do 
    # this for now as it will only be a problem if the user 
    # switches from shiny to not-shiny mode (and even then likely
    # won't matter)
    import builtins
    builtins._display_if_has_repr_html = _display_if_has_repr_html

    class _FunctionDefReprHtml(_ast.NodeTransformer):
      def visit_FunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

      def visit_AsyncFunctionDef(self, node):
        node.decorator_list.insert(
          0,
          _ast.Name(id="_display_if_has_repr_html", ctx=_ast.Load())
        )
        return node

    ip = get_ipython()
    ip.ast_transformers.append(_FunctionDefReprHtml())

  except:
    pass

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v

  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
globals()["__spec__"] = None
# Out:
# /tmp/ipykernel_105997/1985460196.py:25: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)
# {"/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/_bootstrap.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/_bootstrap_external.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/zipimport.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/codecs.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/encodings/aliases.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/encodings/__init__.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/encodings/utf_8.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/abc.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/io.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/stat.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/_collections_abc.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/genericpath.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/posixpath.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/os.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/_sitebuiltins.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/encodings/utf_8_sig.py": 1704067200.0, "/home/nick/repos/blog/.venv/lib/python3.13/site-packages/_virtualenv.py": 1775868049.4503257, "/home/nick/repos/blog/.venv/lib/python3.13/site-packages/_distutils_hack/__init__.py": 1774855538.540388, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/site.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/__init__.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/machinery.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/_abc.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/types.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/importlib/util.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/runpy.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/keyword.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/operator.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/reprlib.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/collections/__init__.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/functools.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/contextlib.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/enum.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/re/_constants.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/re/_parser.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/re/_casefix.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/re/_compiler.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/copyreg.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/re/__init__.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/fnmatch.py": 1704067200.0, "/home/nick/.local/share/mise/installs/python/3.13.12/lib/python3.13/glob.py": 1704067200.0, "/h ...

# %%
PLOTTING_BACKEND = "altair"
SEED = 42

CHAINS = 4
DRAWS = 500
N_RESERVOIRS = 6
N_PRODUCERS = 20

import altair as alt
from src.plotting import theme

alt.data_transformers.disable_max_rows()
theme.apply_lex_altair_theme()

# %%
#| output: false
from datetime import datetime
from resgo.model import (
    Prospect, 
    VolumetricModel, 
    FieldDevelopmentModel, 
    EconomicModel,
    FlatPriceModel,
    FlatRoyaltyModel,
    ProgressiveTaxModel,
    LeverageModel
)
from resgo.plotting import ProspectReporter

prospect = Prospect.default(
    name="Demo Prospect",
    num_reservoirs=N_RESERVOIRS,
    num_producers=N_PRODUCERS,
    dependency=0.4,
    years=30,
)

prospect.volumetric_model = VolumetricModel.default(
    num_reservoirs=N_RESERVOIRS,
    dependency=0.4,
)

prospect.field_development_model = FieldDevelopmentModel.simple_development(
    num_producers=N_PRODUCERS,
    start_date=datetime(2027, 1, 1),
    month_offset=12,
    drill_to_online_months=9,
    max_oil_rate_stbpd=20_000,
    max_gas_rate_mscfpd=90_000,
    gas_development=False,
    producer_capex_USD=45e6,
    years=30,
)

prospect.economic_model = EconomicModel(
    price_model=FlatPriceModel(oil_price_USD_stb=70.0, gas_price_USD_mmbtu=3.5),
    royalty_model=FlatRoyaltyModel(royalty_rate=0.12),
    tax_model=ProgressiveTaxModel(tax_tiers={0: 0.15, 10e6: 0.25, 15e6: 0.4}),
    leverage_model=LeverageModel(debt_to_equity_ratio=1.0, interest_rate=0.06, loan_term_years=15),
    infrastructure_capex_USD=60e6,
    annual_discount_rate=0.10,
    annual_inflation_rate=0.025,
    annual_opex_USD=2_000_000,
    producer_abandonment_cost_USD=500_000,
)

simpack = prospect.simulate(
    risked=True, 
    levered=True, 
    chains=CHAINS, 
    draws=DRAWS,
    seed=SEED
)
reporter = ProspectReporter(prospect, simpack)
# Out:
# 2026-05-28 17:29:43.238 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 1 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.243 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 2 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.247 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 3 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.252 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 4 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.256 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 5 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.261 | INFO     | resgo.engine.volumetric_simulator:simulate_reservoir:136 - Zone 6 reservoir volumetric simulation complete.
# 2026-05-28 17:29:43.266 | INFO     | resgo.engine.volumetric_simulator:simulate:80 - Volumetric results are risked so are masked with Outcome array.
# 2026-05-28 17:29:43.267 | SUCCESS  | resgo.engine.volumetric_simulator:simulate:85 - Demo Prospect volumetric simulation complete!
# 2026-05-28 17:29:43.558 | INFO     | resgo.engine.production_simulator:prepare_simpack:146 - Merged VolumetricSimulator dataset into ProductionSimulator dataset.
# 2026-05-28 17:29:43.559 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 1 start_idx = 8
# 2026-05-28 17:29:43.559 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 2 start_idx = 20
# 2026-05-28 17:29:43.559 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 3 start_idx = 32
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 4 start_idx = 44
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 5 start_idx = 56
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 6 start_idx = 68
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 7 start_idx = 79
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 8 start_idx = 91
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 9 start_idx = 103
# 2026-05-28 17:29:43.560 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 10 start_idx = 115
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 11 start_idx = 127
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 12 start_idx = 139
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 13 start_idx = 150
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 14 start_idx = 162
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 15 start_idx = 174
# 2026-05-28 17:29:43.561 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 16 start_idx = 186
# 2026-05-28 17:29:43.562 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 17 start_idx = 198
# 2026-05-28 17:29:43.562 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 18 start_idx = 209
# 2026-05-28 17:29:43.562 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 19 start_idx = 221
# 2026-05-28 17:29:43.562 | DEBUG    | resgo.engine.production_simulator:get_producer_start_indices:210 - Oil 20 start_idx = 233
# 2026-05-28 17:29:43.581 | INFO     | resgo.engine.production_simulator:initialize_flowing_array:236 - Flowing array initialized.
# 2026-05-28 17:29:43.589 | INFO     | resgo.engine.production_simulator:simulate_recovery_factors:425 - Recovery factors simulated.
# 2026-05-28 17:29:43.940 | INFO     | resgo.engine.production_simulator:initialize_oil_well_rates:308 - Oil well rates initialized.
# 2026-05-28 17:29:43.940 | DEBUG    | resgo.engine.production_simulator:initialize_gas_well_rates:324 - No gas producers, skipping gas rate initialization...
# 2026-05-28 17:29:43.940 | INFO     | resgo.engine.production_simulator:simulate:88 - Commencing field production simulation (20 oil, 0 gas producers)...
# Chain 0:   0%|                                                                                                                | 0/360 [00:00<?, ?it/s]
# Chain 0:   7%|███████▏                                                                                               | 25/360 [00:00<00:05, 60.47it/s]
# Chain 0:   4%|███▋                                                                                                  | 13/360 [00:00<00:03, 113.78it/s]
# Chain 0:   9%|█████████▍                                                                                             | 33/360 [00:00<00:06, 54.23it/s]
# Chain 0:  11%|███████████▍                                                                                           | 40/360 [00:00<00:06, 49.67it/s]
# Chain 0:  13%|█████████████▏                                                                                         | 46/360 [00:00<00:06, 47.47it/s]
# Chain 0:  14%|██████████████▌                                                                                        | 51/360 [00:00<00:06, 46.37it/s]
# Chain 0:  16%|████████████████                                                                                       | 56/360 [00:01<00:06, 45.16it/s]
# Chain 0:  24%|████████████████████████▌                                                                              | 86/360 [00:01<00:06, 42.30it/s]
# Chain 0:  17%|█████████████████▍                                                                                     | 61/360 [00:01<00:06, 44.13it/s]
# Chain 0:  18%|██████████████████▉                                                                                    | 66/360 [00:01<00:06, 43.45it/s]
# Chain 1:   0%|                                                                                                                | 0/360 [00:00<?, ?it/s]
# Chain 1:   3%|███▍                                                                                                  | 12/360 [00:00<00:03, 113.59it/s]
# Chain 0:  20%|████████████████████▎                                                                                  | 71/360 [00:01<00:06, 42.12it/s]
# Chain 0:  21%|█████████████████████▋                                                                                 | 76/360 [00:01<00:06, 42.50it/s]
# Chain 0:  22%|███████████████████████▏                                                                               | 81/360 [00:01<00:06, 42.57it/s]
# Chain 1:   7%|██████▊                                                                                                | 24/360 [00:00<00:06, 53.78it/s]
# Chain 0:  25%|██████████████████████████                                                                             | 91/360 [00:01<00:06, 42.96it/s]
# Chain 1:   9%|████████▊                                                                                              | 31/360 [00:00<00:06, 49.15it/s]
# Chain 0:  27%|███████████████████████████▍                                                                           | 96/360 [00:02<00:06, 43.43it/s]
# Chain 1:  10%|██████████▌                                                                                            | 37/360 [00:00<00:07, 44.73it/s]
# Chain 0:  28%|████████████████████████████▌                                                                         | 101/360 [00:02<00:05, 43.61it/s]
# Chain 1:  12%|████████████                                                                                           | 42/360 [00:00<00:07, 44.31it/s]
# Chain 0:  29%|██████████████████████████████                                                                        | 106/360 [00:02<00:05, 44.31it/s]
# Chain 1:  13%|█████████████▍                                                                                         | 47/360 [00:00<00:07, 43.38it/s]
# Chain 0:  31%|███████████████████████████████▍                                                                      | 111/360 [00:02<00:05, 44.04it/s]
# Chain 1:  14%|██████████████▉                                                                                        | 52/360 [00:01<00:07, 42.35it/s]
# Chain 0:  32%|████████████████████████████████▊                                                                     | 116/360 [00:02<00:05, 44.76it/s]
# Chain 0:  44%|████████████████████████████████████████████▊                                                         | 158/360 [00:03<00:04, 50.25it/s]
# Chain 1:  16%|████████████████▎                                                                                      | 57/360 [00:01<00:07, 41.94it/s]
# Chain 0:  34%|██████████████████████████████████▎                                                                   | 121/360 [00:02<00:05, 45.09it/s]
# Chain 0:  35%|███████████████████████████████████▋                                                                  | 126/360 [00:02<00:05, 46.02it/s]
# Chain 1:  17%|█████████████████▋                                                                                     | 62/360 [00:01<00:07, 41.52it/s]
# Chain 0:  36%|█████████████████████████████████████                                                                 | 131/360 [00:02<00:04, 46.23it/s]
# Chain 2:   0%|                                                                                                                | 0/360 [00:00<?, ?it/s]
# Chain 1:  19%|███████████████████▏                                                                                   | 67/360 [00:01<00:07, 41.40it/s]
# Chain 0:  38%|██████████████████████████████████████▌                                                               | 136/360 [00:02<00:04, 47.04it/s]
# Chain 2:   3%|███▍                                                                                                  | 12/360 [00:00<00:02, 118.70it/s]
# Chain 1:  20%|████████████████████▌                                                                                  | 72/360 [00:01<00:06, 41.31it/s]
# Chain 0:  39%|███████████████████████████████████████▉                                                              | 141/360 [00:03<00:04, 47.29it/s]
# Chain 1:  21%|██████████████████████                                                                                 | 77/360 [00:01<00:06, 41.29it/s]
# Chain 0:  41%|█████████████████████████████████████████▎                                                            | 146/360 [00:03<00:04, 47.13it/s]
# Chain 1:  23%|███████████████████████▍                                                                               | 82/360 [00:01<00:06, 41.22it/s]
# Chain 2:   7%|██████▊                                                                                                | 24/360 [00:00<00:06, 55.63it/s]
# Chain 0:  42%|███████████████████████████████████████████                                                           | 152/360 [00:03<00:04, 48.33it/s]
# Chain 1:  24%|████████████████████████▉                                                                              | 87/360 [00:01<00:06, 41.48it/s]
# Chain 2:   9%|█████████▏                                                                                             | 32/360 [00:00<00:06, 49.54it/s]
# Chain 1:  26%|██████████████████████████▎                                                                            | 92/360 [00:02<00:06, 42.20it/s]
# Chain 0:  46%|██████████████████████████████████████████████▍                                                       | 164/360 [00:03<00:03, 51.52it/s]
# Chain 1:  27%|███████████████████████████▊                                                                           | 97/360 [00:02<00:06, 42.84it/s]
# Chain 0:  47%|████████████████████████████████████████████████▏                                                     | 170/360 [00:03<00:03, 53.19it/s]
# Chain 2:  11%|██████████▊                                                                                            | 38/360 [00:00<00:07, 45.58it/s]
# Chain 1:  28%|████████████████████████████▉                                                                         | 102/360 [00:02<00:05, 43.17it/s]
# Chain 0:  49%|█████████████████████████████████████████████████▊                                                    | 176/360 [00:03<00:03, 55.10it/s]
# Chain 2:  12%|████████████▌                                                                                          | 44/360 [00:00<00:07, 43.57it/s]
# Chain 1:  30%|██████████████████████████████▎                                                                       | 107/360 [00:02<00:05, 43.17it/s]
# Chain 0:  51%|███████████████████████████████████████████████████▊                                                  | 183/360 [00:03<00:03, 57.85it/s]
# Chain 2:  14%|██████████████                                                                                         | 49/360 [00:01<00:07, 42.39it/s]
# Chain 1:  31%|███████████████████████████████▋                                                                      | 112/360 [00:02<00:05, 43.59it/s]
# Chain 0:  53%|█████████████████████████████████████████████████████▊                                                | 190/360 [00:03<00:02, 60.42it/s]
# Chain 2:  15%|███████████████▍                                                                                       | 54/360 [00:01<00:07, 41.53it/s]
# Chain 1:  32%|█████████████████████████████████▏                                                                    | 117/360 [00:02<00:05, 44.72it/s]
# Chain 0:  55%|████████████████████████████████████████████████████████                                              | 198/360 [00:03<00:02, 64.15it/s]
# Chain 0:  57%|██████████████████████████████████████████████████████████                                            | 205/360 [00:04<00:02, 65.72it/s]
# Chain 1:  34%|██████████████████████████████████▌                                                                   | 122/360 [00:02<00:05, 44.76it/s]
# Chain 2:  16%|████████████████▉                                                                                      | 59/360 [00:01<00:07, 39.79it/s]
# Chain 0:  59%|████████████████████████████████████████████████████████████▎                                         | 213/360 [00:04<00:02, 68.56it/s]
# Chain 1:  35%|███████████████████████████████████▉                                                                  | 127/360 [00:02<00:05, 45.78it/s]
# Chain 2:  18%|██████████████████▎                                                                                    | 64/360 [00:01<00:07, 40.34it/s]
# Chain 3:   0%|                                                                                                                | 0/360 [00:00<?, ?it/s]
# Chain 1:  37%|█████████████████████████████████████▍                                                                | 132/360 [00:02<00:04, 46.20it/s]
# Chain 0:  62%|██████████████████████████████████████████████████████████████▉                                       | 222/360 [00:04<00:01, 72.39it/s]
# Chain 2:  19%|███████████████████▋                                                                                   | 69/360 [00:01<00:07, 40.35it/s]
# Chain 3:   3%|███▍                                                                                                  | 12/360 [00:00<00:02, 117.73it/s]
# Chain 0:  64%|█████████████████████████████████████████████████████████████████▏                                    | 230/360 [00:04<00:01, 74.52it/s]
# Chain 1:  38%|██████████████████████████████████████▊                                                               | 137/360 [00:03<00:04, 46.35it/s]
# Chain 2:  21%|█████████████████████▏                                                                                 | 74/360 [00:01<00:07, 40.82it/s]
# Chain 1:  39%|████████████████████████████████████████▏                                                             | 142/360 [00:03<00:04, 47.18it/s]
# Chain 0:  67%|████████████████████████████████████████████████████████████████████                                  | 240/360 [00:04<00:01, 79.28it/s]
# Chain 2:  22%|██████████████████████▌                                                                                | 79/360 [00:01<00:06, 40.97it/s]
# Chain 0:  69%|██████████████████████████████████████████████████████████████████████▊                               | 250/360 [00:04<00:01, 84.67it/s]
# Chain 1:  41%|█████████████████████████████████████████▉                                                            | 148/360 [00:03<00:04, 48.78it/s]
# Chain 3:   7%|██████▊                                                                                                | 24/360 [00:00<00:06, 53.81it/s]
# Chain 2:  23%|████████████████████████                                                                               | 84/360 [00:01<00:06, 41.81it/s]
# Chain 0:  72%|█████████████████████████████████████████████████████████████████████████▋                            | 260/360 [00:04<00:01, 87.19it/s]
# Chain 1:  42%|███████████████████████████████████████████▎                                                          | 153/360 [00:03<00:04, 48.02it/s]
# Chain 2:  25%|█████████████████████████▍                                                                             | 89/360 [00:02<00:06, 42.17it/s]
# Chain 0:  76%|█████████████████████████████████████████████████████████████████████████████                         | 272/360 [00:04<00:00, 94.74it/s]
# Chain 1:  44%|█████████████████████████████████████████████                                                         | 159/360 [00:03<00:04, 49.51it/s]
# Chain 3:   9%|█████████▏                                                                                             | 32/360 [00:00<00:06, 47.92it/s]
# Chain 0:  79%|███████████████████████████████████████████████████████████████████████████████▉                     | 285/360 [00:04<00:00, 104.00it/s]
# Chain 2:  26%|██████████████████████████▉                                                                            | 94/360 [00:02<00:06, 42.76it/s]
# Chain 1:  46%|██████████████████████████████████████████████▊                                                       | 165/360 [00:03<00:03, 50.26it/s]
# Chain 0:  82%|███████████████████████████████████████████████████████████████████████████████████▎                 | 297/360 [00:05<00:00, 108.63it/s]
# Chain 3:  11%|██████████▊                                                                                            | 38/360 [00:00<00:07, 44.30it/s]
# Chain 1:  48%|████████████████████████████████████████████████▍                                                     | 171/360 [00:03<00:03, 51.96it/s]
# Chain 2:  28%|████████████████████████████▎                                                                          | 99/360 [00:02<00:06, 41.26it/s]
# Chain 0:  88%|████████████████████████████████████████████████████████████████████████████████████████▍            | 315/360 [00:05<00:00, 128.11it/s]
# Chain 2:  29%|█████████████████████████████▍                                                                        | 104/360 [00:02<00:06, 42.63it/s]
# Chain 1:  49%|██████████████████████████████████████████████████▍                                                   | 178/360 [00:03<00:03, 54.64it/s]
# Chain 3:  12%|████████████▎                                                                                          | 43/360 [00:00<00:07, 42.74it/s]
# Chain 0:  95%|███████████████████████████████████████████████████████████████████████████████████████████████▋     | 341/360 [00:05<00:00, 165.83it/s]
# Chain 2:  30%|██████████████████████████████▉                                                                       | 109/360 [00:02<00:05, 43.35it/s]
# Chain 1:  51%|████████████████████████████████████████████████████▍                                                 | 185/360 [00:03<00:03, 56.95it/s]
# Chain 3:  13%|█████████████▋                                                                                         | 48/360 [00:01<00:07, 41.78it/s]
# Chain 1:  53%|██████████████████████████████████████████████████████▍                                               | 192/360 [00:04<00:02, 59.66it/s]
# Chain 2:  32%|████████████████████████████████▎                                                                     | 114/360 [00:02<00:05, 43.65it/s]
# Chain 3:  15%|███████████████▏                                                                                       | 53/360 [00:01<00:07, 41.23it/s]
# Chain 1:  55%|████████████████████████████████████████████████████████▍                                             | 199/360 [00:04<00:02, 60.18it/s]
# Chain 2:  33%|█████████████████████████████████▋                                                                    | 119/360 [00:02<00:05, 43.46it/s]
# Chain 3:  16%|████████████████▌                                                                                      | 58/360 [00:01<00:07, 40.02it/s]
# Chain 1:  57%|██████████████████████████████████████████████████████████▎                                           | 206/360 [00:04<00:02, 60.84it/s]
# Chain 2:  34%|███████████████████████████████████▏                                                                  | 124/360 [00:02<00:05, 43.24it/s]
# Chain 3:  18%|██████████████████                                                                                     | 63/360 [00:01<00:07, 38.81it/s]
# Chain 1:  59%|████████████████████████████████████████████████████████████▎                                         | 213/360 [00:04<00:02, 62.32it/s]
# Chain 2:  36%|████████████████████████████████████▌                                                                 | 129/360 [00:02<00:05, 42.73it/s]
# Chain 3:  19%|███████████████████▏                                                                                   | 67/360 [00:01<00:07, 38.25it/s]
# Chain 1:  61%|██████████████████████████████████████████████████████████████▎                                       | 220/360 [00:04<00:02, 64.01it/s]
# Chain 2:  37%|█████████████████████████████████████▉                                                                | 134/360 [00:03<00:05, 41.79it/s]
# Chain 3:  20%|████████████████████▎                                                                                  | 71/360 [00:01<00:07, 37.81it/s]
# Chain 1:  63%|████████████████████████████████████████████████████████████████▌                                     | 228/360 [00:04<00:01, 66.44it/s]
# Chain 2:  39%|███████████████████████████████████████▍                                                              | 139/360 [00:03<00:05, 42.24it/s]
# Chain 3:  21%|█████████████████████▍                                                                                 | 75/360 [00:01<00:07, 36.79it/s]
# Chain 1:  66%|██████████████████████████████████████████████████████████████████▊                                   | 236/360 [00:04<00:01, 68.31it/s]
# Chain 2:  40%|████████████████████████████████████████▊                                                             | 144/360 [00:03<00:05, 41.32it/s]
# Chain 3:  22%|██████████████████████▌                                                                                | 79/360 [00:01<00:07, 36.60it/s]
# Chain 1:  68%|█████████████████████████████████████████████████████████████████████▏                                | 244/360 [00:04<00:01, 70.01it/s]
# Chain 2:  41%|██████████████████████████████████████████▏                                                           | 149/360 [00:03<00:04, 42.75it/s]
# Chain 3:  23%|███████████████████████▋                                                                               | 83/360 [00:01<00:07, 37.23it/s]
# Chain 1:  70%|███████████████████████████████████████████████████████████████████████▋                              | 253/360 [00:04<00:01, 74.76it/s]
# Chain 2:  43%|███████████████████████████████████████████▋                                                          | 154/360 [00:03<00:04, 42.93it/s]
# Chain 3:  24%|████████████████████████▉                                                                              | 87/360 [00:02<00:07, 37.54it/s]
# Chain 1:  73%|██████████████████████████████████████████████████████████████████████████▌                           | 263/360 [00:05<00:01, 80.94it/s]
# Chain 2:  44%|█████████████████████████████████████████████                                                         | 159/360 [00:03<00:04, 43.19it/s]
# Chain 3:  25%|██████████████████████████                                                                             | 91/360 [00:02<00:07, 37.85it/s]
# Chain 1:  76%|█████████████████████████████████████████████████████████████████████████████▋                        | 274/360 [00:05<00:00, 88.07it/s]
# Chain 3:  26%|███████████████████████████▏                                                                           | 95/360 [00:02<00:07, 37.62it/s]
# Chain 2:  46%|██████████████████████████████████████████████▊                                                       | 165/360 [00:03<00:04, 45.40it/s]
# Chain 1:  79%|█████████████████████████████████████████████████████████████████████████████████                     | 286/360 [00:05<00:00, 95.93it/s]
# Chain 1:  83%|████████████████████████████████████████████████████████████████████████████████████▏                | 300/360 [00:05<00:00, 106.67it/s]
# Chain 3:  28%|████████████████████████████▎                                                                         | 100/360 [00:02<00:06, 39.29it/s]
# Chain 2:  48%|████████████████████████████████████████████████▍                                                     | 171/360 [00:03<00:03, 47.28it/s]
# Chain 1:  87%|████████████████████████████████████████████████████████████████████████████████████████             | 314/360 [00:05<00:00, 115.70it/s]
# Chain 3:  29%|█████████████████████████████▍                                                                        | 104/360 [00:02<00:06, 39.26it/s]
# Chain 2:  49%|██████████████████████████████████████████████████▏                                                   | 177/360 [00:03<00:03, 48.28it/s]
# Chain 1:  92%|█████████████████████████████████████████████████████████████████████████████████████████████▍       | 333/360 [00:05<00:00, 135.45it/s]
# Chain 3:  30%|██████████████████████████████▉                                                                       | 109/360 [00:02<00:06, 39.75it/s]
# Chain 2:  51%|███████████████████████████████████████████████████▊                                                  | 183/360 [00:04<00:03, 50.65it/s]
# Chain 1: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 360/360 [00:05<00:00, 173.72it/s]
# Chain 2:  52%|█████████████████████████████████████████████████████▌                                                | 189/360 [00:04<00:03, 52.31it/s]
# Chain 3:  32%|████████████████████████████████▎                                                                     | 114/360 [00:02<00:06, 39.90it/s]
# Chain 2:  54%|███████████████████████████████████████████████████████▏                                              | 195/360 [00:04<00:03, 54.36it/s]
# Chain 3:  33%|█████████████████████████████████▋                                                                    | 119/360 [00:02<00:05, 40.51it/s]
# Chain 2:  56%|█████████████████████████████████████████████████████████▏                                            | 202/360 [00:04<00:02, 58.19it/s]
# Chain 3:  34%|███████████████████████████████████▏                                                                  | 124/360 [00:02<00:05, 42.04it/s]
# Chain 2:  58%|███████████████████████████████████████████████████████████▏                                          | 209/360 [00:04<00:02, 60.94it/s]
# Chain 3:  36%|████████████████████████████████████▌                                                                 | 129/360 [00:03<00:05, 42.22it/s]
# Chain 2:  60%|█████████████████████████████████████████████████████████████▍                                        | 217/360 [00:04<00:02, 64.26it/s]
# Chain 3:  37%|█████████████████████████████████████▉                                                                | 134/360 [00:03<00:05, 42.61it/s]
# Chain 2:  62%|███████████████████████████████████████████████████████████████▊                                      | 225/360 [00:04<00:02, 66.08it/s]
# Chain 3:  39%|███████████████████████████████████████▍                                                              | 139/360 [00:03<00:05, 43.54it/s]
# Chain 2:  65%|██████████████████████████████████████████████████████████████████                                    | 233/360 [00:04<00:01, 69.26it/s]
# Chain 3:  40%|████████████████████████████████████████▊                                                             | 144/360 [00:03<00:04, 43.46it/s]
# Chain 2:  67%|████████████████████████████████████████████████████████████████████▎                                 | 241/360 [00:04<00:01, 70.53it/s]
# Chain 3:  41%|██████████████████████████████████████████▏                                                           | 149/360 [00:03<00:04, 43.17it/s]
# Chain 2:  69%|██████████████████████████████████████████████████████████████████████▊                               | 250/360 [00:05<00:01, 74.00it/s]
# Chain 3:  43%|███████████████████████████████████████████▋                                                          | 154/360 [00:03<00:04, 43.99it/s]
# Chain 2:  72%|█████████████████████████████████████████████████████████████████████████▋                            | 260/360 [00:05<00:01, 79.65it/s]
# Chain 3:  44%|█████████████████████████████████████████████                                                         | 159/360 [00:03<00:04, 45.34it/s]
# Chain 2:  75%|████████████████████████████████████████████████████████████████████████████▌                         | 270/360 [00:05<00:01, 85.17it/s]
# Chain 3:  46%|██████████████████████████████████████████████▍                                                       | 164/360 [00:03<00:04, 46.46it/s]
# Chain 2:  78%|███████████████████████████████████████████████████████████████████████████████▎                      | 280/360 [00:05<00:00, 86.95it/s]
# Chain 3:  47%|███████████████████████████████████████████████▉                                                      | 169/360 [00:03<00:04, 45.92it/s]
# Chain 2:  81%|██████████████████████████████████████████████████████████████████████████████████▋                   | 292/360 [00:05<00:00, 95.77it/s]
# Chain 3:  49%|█████████████████████████████████████████████████▌                                                    | 175/360 [00:04<00:03, 48.12it/s]
# Chain 2:  85%|██████████████████████████████████████████████████████████████████████████████████████▏              | 307/360 [00:05<00:00, 110.94it/s]
# Chain 3:  50%|███████████████████████████████████████████████████▎                                                  | 181/360 [00:04<00:03, 49.88it/s]
# Chain 2:  90%|██████████████████████████████████████████████████████████████████████████████████████████▉          | 324/360 [00:05<00:00, 127.82it/s]
# Chain 3:  52%|████████████████████████████████████████████████████▉                                                 | 187/360 [00:04<00:03, 51.43it/s]
# Chain 2:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████▎   | 347/360 [00:05<00:00, 157.42it/s]
# Chain 3:  54%|██████████████████████████████████████████████████████▉                                               | 194/360 [00:04<00:02, 55.55it/s]
# Chain 3:  56%|████████████████████████████████████████████████████████▋                                             | 200/360 [00:04<00:02, 56.50it/s]
# Chain 3:  57%|██████████████████████████████████████████████████████████▋                                           | 207/360 [00:04<00:02, 59.94it/s]
# Chain 3:  60%|████████████████████████████████████████████████████████████▉                                         | 215/360 [00:04<00:02, 63.52it/s]
# Chain 3:  62%|██████████████████████████████████████████████████████████████▉                                       | 222/360 [00:04<00:02, 65.26it/s]
# Chain 3:  64%|█████████████████████████████████████████████████████████████████▏                                    | 230/360 [00:04<00:01, 68.90it/s]
# Chain 3:  66%|███████████████████████████████████████████████████████████████████▍                                  | 238/360 [00:05<00:01, 72.10it/s]
# Chain 3:  69%|█████████████████████████████████████████████████████████████████████▉                                | 247/360 [00:05<00:01, 76.55it/s]
# Chain 3:  71%|████████████████████████████████████████████████████████████████████████▌                             | 256/360 [00:05<00:01, 78.60it/s]
# Chain 3:  74%|███████████████████████████████████████████████████████████████████████████▎                          | 266/360 [00:05<00:01, 83.85it/s]
# Chain 3:  77%|██████████████████████████████████████████████████████████████████████████████▊                       | 278/360 [00:05<00:00, 92.67it/s]
# Chain 3:  81%|██████████████████████████████████████████████████████████████████████████████████▏                  | 293/360 [00:05<00:00, 107.90it/s]
# Chain 3:  87%|███████████████████████████████████████████████████████████████████████████████████████▌             | 312/360 [00:05<00:00, 130.19it/s]
# Chain 3:  93%|██████████████████████████████████████████████████████████████████████████████████████████████▎      | 336/360 [00:05<00:00, 161.10it/s]
# 2026-05-28 17:29:57.479 | SUCCESS  | resgo.engine.production_simulator:simulate:105 - Demo Prospect Field production simulation complete!
# 2026-05-28 17:29:57.612 | INFO     | resgo.engine.economic_simulator:initialize_factor_curves:318 - Discount and inflation curves initialized
# 2026-05-28 17:29:59.792 | INFO     | resgo.engine.economic_simulator:simulate_capex:378 - CAPEX payments calculated with leverage: 1.0 Debt:Equity.
# 2026-05-28 17:30:00.154 | INFO     | resgo.engine.economic_simulator:simulate_leverage:392 - Debt repayments simulated.
# 2026-05-28 17:30:00.155 | DEBUG    | resgo.engine.economic_simulator:simulate_prices:405 - An additional 7 months of prices will be simulated before development begins.
# 2026-05-28 17:30:00.158 | INFO     | resgo.engine.economic_simulator:simulate_prices:420 - Oil and Gas prices simulated using a flat price model.
# 2026-05-28 17:30:00.452 | INFO     | resgo.engine.economic_simulator:simulate_gross_sales:446 - Gross sales simulated.
# 2026-05-28 17:30:00.468 | INFO     | resgo.engine.economic_simulator:simulate_expenses:465 - OPEX and ABEX simulated.
# 2026-05-28 17:30:00.636 | INFO     | resgo.engine.economic_simulator:simulate_royalty_payments:490 - Royalties simulated using a flat royalty model.
# 2026-05-28 17:30:00.869 | INFO     | resgo.engine.economic_simulator:simulate_capital_depreciation:516 - Infrastructure depreciation model simulated.
# 2026-05-28 17:30:01.118 | INFO     | resgo.engine.economic_simulator:simulate_capital_depreciation:530 - Producer depreciation model simulated.
# 2026-05-28 17:30:01.196 | INFO     | resgo.engine.economic_simulator:simulate_tax_payments:541 - Taxes simulated using a progressive tax model.
# 2026-05-28 17:30:01.196 | SUCCESS  | resgo.engine.economic_simulator:simulate:302 - Economic simulation of Demo Prospect complete!

# %%
fig = reporter.plotter.forest_plot(
    "Net (m)", 
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.LayerChart(...)

# %%
fig = reporter.plotter.forest_plot(
    "Porosity", 
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.LayerChart(...)

# %%
fig = reporter.plotter.forest_plot(
    "Water Saturation", 
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.LayerChart(...)

# %%
fig = reporter.plotter.forest_plot(
    "STOIIP (stb)", 
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.LayerChart(...)

# %%
fig = reporter.plotter.prospect_volumetric_ecdf_plot(
    figsize=(650, 250),
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.LayerChart(...)

# %%
fig = reporter.plotter.combined_production_plot(
    figsize=(650, 250),
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.VConcatChart(...)

# %%
fig = reporter.plotter.combined_cash_flow_plot(
    figsize=(650, 250),
    backend=PLOTTING_BACKEND
)
fig.show()
# Out:
# alt.VConcatChart(...)

# %%
reporter.tabler.volumetrics_table()
# Out:
#                                    P(Success)   P99    P90    P50    P10  \
# stream
# STOIIP (stb)        Total Volumes         1.0  41.5   83.4  166.8  283.5
# GIIP (mscf)         Total Volumes         1.0  15.1   33.5   72.3  132.9
# Condensate (stb)    Total Volumes         1.0   0.4    1.1    2.5    5.2
# Solution Gas (mscf) Total Volumes         1.0  61.8  143.8  304.5  563.2
#
#                                       P1
# stream
# STOIIP (stb)        Total Volumes  448.5
# GIIP (mscf)         Total Volumes  219.9
# Condensate (stb)    Total Volumes   10.2
# Solution Gas (mscf) Total Volumes  918.0

# %%
reporter.tabler.oil_eur_table(group_by=None)
# Out:
#                P(Success)  P99   P90   P50   P10     P1
# Total Oil EUR         1.0  9.0  18.3  39.7  68.4  109.9

# %%
reporter.tabler.oil_eur_table(group_by="reservoir")
# Out:
#            P(Success)  P99  P90   P50   P10    P1
# reservoir
# Zone 1           0.91  0.5  1.9   5.8  16.5  33.3
# Zone 2           0.57  1.7  3.8  10.3  26.0  53.9
# Zone 3           0.50  0.9  2.6   7.1  18.3  34.8
# Zone 4           0.85  0.7  2.2   6.7  19.3  47.2
# Zone 5           0.73  1.4  3.4   9.6  24.2  60.8
# Zone 6           0.74  0.7  2.3   6.2  15.4  33.6

# %%
reporter.tabler.npv_table()
# Out:
#      P(Commercial)    P99   P90    P50     P10      P1
# NPV           0.89 -413.0 -23.0  671.0  1452.0  2197.0

# %%
reporter.tabler.emv_table()
# Out:
#      P(Commercial)    P99   P90    P50     P10      P1
# EMV           0.89 -372.0 -25.0  590.0  1285.0  1946.0

# %%
from resgo.plotting.tables import npv_USD
import pandas as pd

npv = npv_USD(
    simpack,
    nominal=True,
    discounted=True,
    success_only=False,
)
npv_df = pd.DataFrame({"npv_usd_mm": npv.to_numpy().ravel() / 1e6})

histogram = (
    alt.Chart(npv_df)
    .mark_bar(color="#FACC15", opacity=0.85)
    .encode(
        x=alt.X(
            "npv_usd_mm:Q",
            bin=alt.Bin(maxbins=60),
            title="Nominal discounted NPV ($USD MM)",
        ),
        y=alt.Y("count():Q", title="Simulation count"),
        tooltip=[alt.Tooltip("count():Q", title="Count")],
    )
    .properties(
        width=650,
        height=250,
        title="Simulated NPV Distribution",
    )
)

break_even = (
    alt.Chart(pd.DataFrame({"npv_usd_mm": [0]}))
    .mark_rule(color="red", strokeDash=[6, 4], strokeWidth=2)
    .encode(x="npv_usd_mm:Q")
)

fig = alt.layer(histogram, break_even)
fig.show()
# Out:
# alt.LayerChart(...)
